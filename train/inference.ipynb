# %%
import spacy

# %%
from pypdf import PdfReader
import pypdf
import logging

logging.getLogger("pypdf._reader").setLevel(logging.ERROR)

def convert_pdf_to_text(file_path: str) -> None:
    """
    This function converts PDF file to string. 
    Because email and name must appear on the first page so, return information only on the first page. 
    
    Args:
        file_path: path of pdf file
    """
    
    reader = PdfReader(file_path)

    page = reader.pages[0] # only on first page
    text = page.extract_text()
    
    text = text.replace("\n"," ")
    text = text.replace("\r", " ")
    text = " ".join(text.split(" "))
    return text

# %%
def predict(model, file_path):
    text = convert_pdf_to_text(file_path)
    predictions = model(text) 
    predictions = predictions.to_json()['ents']

    for i in range(len(predictions)):
        result = predictions[i]
        start = result['start']
        end = result['end']
        label = result['label']
        text_result = text[start:end]

        if label == "Email":
            text_result = "".join(text_result.split(" "))

        print(f" - {label}: {text_result}")

# %%
import os

def predict_in_folder(model, folder_path):
    list_files = os.listdir(folder_path)

    for pdf_path in list_files:
        base_pdf_path = os.path.join(folder_path,pdf_path)
        print(f"At {pdf_path}:")
        predict(model, base_pdf_path)

# %%
model = spacy.load("output/model-best") #load the best model

# %%
predict(model,'resumes/android_01.pdf')
# Out:
#  - Name: Nguyen Thanh Xuan
#  - Email: xuanusm@gmail.com

# %%
predict_in_folder(model, 'resumes')
# Out:
# At android_01.pdf:
#  - Name: Nguyen Thanh Xuan
#  - Email: xuanusm@gmail.com
# At android_02.pdf:
#  - Name: Hoàng Văn Dương
#  - Email: duonghv@fsoft.com.vn
# At android_03.pdf:
#  - Email: kimtungcdt@gmail.com
#  - Name: Le Kim Tung
# At android_04.pdf:
#  - Name: TRUONG THANH NGUYEN
# At android_05.pdf:
#  - Name: Toan Tran
#  - Email: me@toan.mobi
# At android_06.pdf:
#  - Name: Nguyen Dang Phat
#  - Email: phatnd89@gmail.com
# At android_07.pdf:
#  - Name: Tran  Chi Cao
#  - Email: cao.tranchi@gmail.com
# At android_09.pdf:
#  - Name: DO HOANG YEN
#  - Email: dohoangyen93@gmail.com
# At android_10.pdf:
#  - Name: HUỲNH THÁI TÂM
#  - Email: tel.2406@gmail.com
# At android_11.pdf:
#  - Name: BUI DUNG ANH TUAN
#  - Email: anhtuanbd84@gmail.com
# At android_12.pdf:
#  - Name: Hoàng Thanh Tùng
#  - Email: tung.hoangthanh90@gmail.com
# At android_13.pdf:
#  - Name: HUỲNH VĂN TOÀN
#  - Email: huynhvantoan.itc@gmail.com
# At android_14.pdf:
#  - Name: NGUYỄN CÔNG SƠN
#  - Email: sonnguyen1187@gmail.com
# At android_15.pdf:
#  - Name: SINH TIEN HO70
#  - Email: SINHTIENHO@GMAIL.COM
# At android_16.pdf:
#  - Name: NGO MINH HIEN
#  - Email: nmhien88@gmail.com
# At android_17.pdf:
#  - Name: Pham Trung Truc
#  - Email: pttruc87@gmail.com
# At android_18.pdf:
#  - Email: ngco.binh@yahoo.com
# At android_19.pdf:
# At android_20.pdf:
#  - Name: LE VINH NGHIEM
#  - Email: le.vinhnghiem@gmail.com
# At android_21.pdf:
#  - Name: Khai Kim Hoang
#  - Email: hoangkimkhai276@gmail.com
# At android_22.pdf:
#  - Name: NGUYEN MINH THONG
#  - Email: playerthong@yahoo.com
# At android_23.pdf:
#  - Name: TRẦN QUỐC NGUYỆN
#  - Email: nguyenpc2010@gmail.com
#  - Email: nguyenpc2010@gmail.com
# At android_24.pdf:
#  - Name: Nguyen Cong Y
#  - Email: congy94@gmail.com
# At android_25.pdf:
#  - Name: LE TRUNG THU
#  - Email: thult304@yahoo.com
# At android_26.pdf:
#  - Name: Nguyễn Văn Tú
#  - Email: caybangmuathuqn@gmail.com
# At android_27.pdf:
#  - Name: NGUYEN MINH BINH
#  - Email: nmbinh87@gmail.com
# At android_28.pdf:
#  - Name: Hoang Dung Phi
#  - Email: hoangdungphi2511@gmail.com
# At android_29.pdf:
#  - Name: DANH	NGUYEN
#  - Email: dnncntt@gmail.com
# At android_30.pdf:
#  - Email: tienhoa25290@gmail.com
# At android_31.pdf:
#  - Name: Tran Nam
#  - Email: namtran09061992@gmail.com
# At android_32.pdf:
#  - Name: ĐỖ ĐẶNG MINH
#  - Email: masterminh219@gmail.com
# At android_33.pdf:
# At android_34.pdf:
#  - Name: NGUYEN NHAT TUAN
#  - Email: nguyennhattuan0504@gmail.com
# At android_35.pdf:
#  - Name: NGUYEN MINH DUC
#  - Email: minhduc1827@gmail.com
# At android_36.pdf:
#  - Name: Binh Nguyen Dinh
#  - Email: ndbinh99@gmail.com
# At android_37.pdf:
#  - Email: tvkhanhit@gmail.com
# At android_38.pdf:
#  - Name: NGUY ỄN VĂN DUY
#  - Email: nguyenvanduy.vtk33dlu@gmail.com
# At android_39.pdf:
#  - Email: bdqnghi@apcs.vn
#  - Name: Bùi Duy Quốc Nghị
# At android_40.pdf:
#  - Name: CHENH HENH PHAT
#  - Email: Hungphat812@gmail.com
# At android_41.pdf:
#  - Email: info@titancorp.vn
#  - Name: Pho Tran Van
# At android_42.pdf:
#  - Name: Trần Xuân Vinh
#  - Email: xvinhtran@hotmail.com
# At android_43.pdf:
#  - Name: Hoa, Le Tien
#  - Email: tienhoa25290@gmail.com
# At android_44.pdf:
#  - Name: NGUYỄN TUẤN ANH
#  - Email: tuananh23791@gmail.com
# At android_45.pdf:
#  - Name: Thai Ly Cuong
#  - Email: thailycuong1202@gmail.com
# At android_46.pdf:
#  - Name: Lê Duy Hoàng
#  - Email: hoangld.dev@gmail.com
# At android_47.pdf:
#  - Name: LUU THANH NHUT
#  - Email: seafec2014@gmail.com
# At android_48.pdf:
#  - Name: TUAN HUYNH VAN
#  - Email: entec_vtuan@gmail.com
# At android_49.pdf:
#  - Name: TRẦN NGUYÊN THANH TÂM
#  - Email: sawyerkiss87@gmail.com
# At android_50.pdf:
#  - Name: Loi NguyenHo
#  - Email: vanloi999@gmail.com
# At C#_01.pdf:
#  - Name: Khai Le
#  - Name: Khai Le Quang
#  - Email: khai.le@live.com
# At C#_02.pdf:
#  - Name: Ngo Thien Bao
#  - Email: bao.ngothien@gmail.com
# At C#_03.pdf:
#  - Name: Son Bui Ngoc
#  - Email: sonbn91@gmail.com
# At C#_04.pdf:
#  - Name: Tran Lo Giang
#  - Email: giangtl@gmail.com
# At C#_05.pdf:
#  - Name: TRAN HUU HOANG
#  - Email: huuhoangtran_86dl@yahoo.com.vn
# At C#_06.pdf:
#  - Name: Tung-ngthanh
#  - Email: Tungh2@gmail.com
# At C#_07.pdf:
#  - Name: Tran Anh Tuan
#  - Email: trananhtuan.v1@gmail.com
# At C#_08.pdf:
# At C#_09.pdf:
#  - Name: Tri Minh Nguyen
#  - Email: minhtri.mtn@hotmail.com
# At C#_10.pdf:
#  - Name: Bui Duy Quy
# At C#_11.pdf:
#  - Name: DO HUY HUNG
#  - Email: hungdh1405@gmail.com
# At C#_12.pdf:
#  - Name: PHẠM BÁ LẬP
#  - Email: lappb172@gmail.com
# At C#_13.pdf:
#  - Name: Nguyen Pham Minh Hieu
#  - Email: 0912144@gmail.com
# At C#_14.pdf:
#  - Name: Dinh Quang Long
#  - Email: longbalan@gmail.com
# At C#_15.pdf:
#  - Name: ĐỖ VĂN QUỐC
#  - Email: quocboy159@gmail.com
# At C#_16.pdf:
#  - Name: Bao Ngo Thien
#  - Email: bao.ngothien@gmail.com
# At C#_17.pdf:
#  - Name: CUONG LAM THANH
#  - Email: thanhcuong1990@gmail.com
# At C#_18.pdf:
#  - Name: Lâm Tuấn Phong
#  - Email: honglele22@yahoo.com
# At C#_19.pdf:
#  - Name: NAMEHoang Trong The
# At C#_20.pdf:
#  - Email: vanlinh.dev.vn@gmail.com
# At C#_21.pdf:
#  - Name: LE VAN LONG
#  - Email: levanlongktmt@gmail.com
# At C#_22.pdf:
#  - Name: NGUYEN THE TRINH
#  - Name: Nguyen The Trinh
#  - Email: trinhnguyenthe@gmail.com
# At C#_23.pdf:
#  - Email: Dangthanh.do@hotmail.com
# At C#_24.pdf:
#  - Name: Trần Việt Dũng
#  - Email: vietdung1508@gmail.com
# At C#_25.pdf:
#  - Name: Do Van Quyen
# At C#_26.pdf:
#  - Name: Huynh Tan An
#  - Email: huynhtanan90@gmail.com
# At C#_27.pdf:
#  - Name: Vinh Nguyen  Van
#  - Email: nvvinhit2020@gmail.com
# At C#_28.pdf:
#  - Name: Hoang Nguyen
#  - Email: ngoochooang@gmail.com
# At C#_29.pdf:
#  - Name: NGUYEN PHAN KY
#  - Email: danitthehemoi@gmail.com
# At C#_30.pdf:
#  - Name: Tran Lo Giang
# At C#_31.pdf:
#  - Name: Thien  Do Duc
#  - Email: thienddfu@gmail.com
# At C#_32.pdf:
#  - Name: LE BAO TOAN
#  - Email: toan.lee@outlook.com
# At C#_33.pdf:
#  - Name: Pham Anh Tho
#  - Email: phamanhtho@gmail.com
#  - Email: pham.anh.tho@hotmail.com
# At C#_34.pdf:
#  - Email: truongductai.vn@gmail.com
# At C#_35.pdf:
#  - Name: NGUYỄN VĂN HÙNG
#  - Email: abrightnewdawn@gmail.com
# At C#_36.pdf:
#  - Name: TRẦN DUY TRƯỜNG
# At C#_37.pdf:
#  - Name: Tran Nguyen Thanh Tung
#  - Email: leonblue311@yahoo.com
# At C#_38.pdf:
#  - Name: Dang Tuan Anh
#  - Email: Anhdt.it@gmail.com
# At C#_39.pdf:
#  - Name: TRAN VUONG QUOC ANH
#  - Email: dien251@yahoo.com
# At C#_40.pdf:
#  - Name: An Nguyen
# At C#_41.pdf:
#  - Name: Lâm Tấn Hảo
#  - Email: haolamtan@gmail.co
# At C#_42.pdf:
#  - Name: Le Cong Nguyen
#  - Email: milldol84@gmail.com
# At C#_43.pdf:
#  - Name: Huynh Tan An
#  - Email: huynhtanan90@gmail.com
# At C#_44.pdf:
#  - Name: NGUYEN THANH VU
#  - Email: ngthanhvu@gmail.com
# At C#_45.pdf:
#  - Name: TRINH QUOC HOA
#  - Email: quochoa15@yahoo.com
# At C#_46.pdf:
#  - Name: PHAM VAN HUNG
#  - Name: PHAM VAN HUNG
# At C#_47.pdf:
#  - Name: NGUYEN THI MINH KHUE
#  - Email: minhkhue1234@gmail.com
# At C#_48.pdf:
# At C#_49.pdf:
#  - Name: Tran Phuc Ho
# At C#_50.pdf:
#  - Name: Nguyen Xuan Vi et
#  - Email: xuanviet1981@gmail.com
# At html_js_css_01.pdf:
#  - Name: Anh Nguyen
#  - Email: anhnguyen.tb90@gmail.com
# At html_js_css_02.pdf:
#  - Email: dinhluan1989@gmail.com
#  - Name: LUAN DINH CHI
# At html_js_css_03.pdf:
#  - Email: vhquan89@gmail.com
#  - Name: Nguyen Trong Nhan
#  - Email: nguyentrongnhandesigner@gmail.com
# At html_js_css_04.pdf:
#  - Email: chcuong@apcs.vn
# At html_js_css_05.pdf:
#  - Name: TRẦN CƯƠNG TR ỰC
#  - Email: cuongtruc.tran@gmail.com
# At html_js_css_06.pdf:
#  - Name: NGUYỄN HOÀNG MINH
#  - Email: minhnguyen090991@gmail.com
# At html_js_css_07.pdf:
#  - Name: GIANG NGUYEN
#  - Email: giangnm@live.com
# At html_js_css_09.pdf:
#  - Email: nhanlt1710@gmail.com
# At html_js_css_10.pdf:
#  - Name: Le Hai Thinh
#  - Name: Lê Hải Thịnh
#  - Email: hans.thinhle@gmail.com
# At html_js_css_11.pdf:
#  - Name: Nguyen Thanh Trung
#  - Email: trungnguyenthanh70@gmail.com
# At html_js_css_12.pdf:
#  - Name: Sang Lê Nguyễn Vĩnh
#  - Email: sanglnv.87@gmail.com
# At html_js_css_13.pdf:
#  - Name: LÊ ANH PHƯỚC
#  - Email: phuoc852312@gmail.com
# At html_js_css_14.pdf:
#  - Name: LÊ HỮU PHÚC
#  - Email: lehuuphucaptech@gmail.com
# At html_js_css_15.pdf:
#  - Name: Duong Hong Thinh
#  - Email: thinhduong223@gmail.com
# At html_js_css_16.pdf:
#  - Email: phamchanh6599@gmail.com
#  - Name: Phạm Nguyễn Phúc Chánh
# At html_js_css_17.pdf:
#  - Name: Huy Minh Bui
#  - Email: minhhuybui@gmail.com
# At html_js_css_18.pdf:
# Advanced encoding /SymbolSetEncoding not implemented yet
#  - Name: TRƯƠNG ĐẶNG NGUYỄN
#  - Email: dangnguyenful@gmail.com
# At html_js_css_19.pdf:
#  - Name: NGUYEN HONG NHAT THANH
#  - Email: nhatthanh510@gmail.com
# At html_js_css_20.pdf:
#  - Name: TIEN DO QUYET
#  - Email: Tiendo1011@gmail.com
# At html_js_css_21.pdf:
#  - Name: Tran Phuoc Tu
#  - Email: tranphuoctu@gmail.com
# At html_js_css_22.pdf:
#  - Name: Sang Lê Nguyễn Vĩnh
#  - Email: sanglnv.87@gmail.com
# At html_js_css_23.pdf:
#  - Name: Thang Hoang Cao
# At html_js_css_24.pdf:
#  - Name: Nguyen Minh Triet
#  - Email: petertriet@gmail.com
#  - Email: petertriet@gmail.com
# At html_js_css_25.pdf:
# At html_js_css_26.pdf:
#  - Name: Nguyen Minh Thang
# At html_js_css_27.pdf:
#  - Name: NGUYỄN BÌNH VĨ
# At html_js_css_28.pdf:
#  - Name: Mai	Gia	Tran
#  - Email: maigiatran@gmail.com
# At html_js_css_29.pdf:
#  - Name: Lam Nguyen Tien
# At html_js_css_30.pdf:
#  - Name: TRAN QUANG MINH
#  - Email: mtran8@binghamton.edu
# At html_js_css_31.pdf:
#  - Name: Vinh Bui Quang
#  - Email: vinhbq1902@gmail.com
# At html_js_css_32.pdf:
#  - Name: Trần Bắc Sơn
#  - Email: mail@tbson.info
# At html_js_css_33.pdf:
# At html_js_css_34.pdf:
#  - Name: 1Nguyen Hien
#  - Email: cptrodgers@gmail.com
# At html_js_css_36.pdf:
#  - Email: mail.com
#  - Name: DANG XUAN TRAN
#  - Name: Dang Xuan Tran
# At html_js_css_37.pdf:
#  - Name: Võ Thanh Hoàng Trung
#  - Email: hoangtrung.uit@gmail.com
# At html_js_css_38.pdf:
#  - Name: Ho Viet Tuan
#  - Email: tuanhung9293@gmail.com
# At html_js_css_39.pdf:
#  - Name: Su Tran
#  - Email: trannguyentiensu@gmail.com
# At html_js_css_40.pdf:
#  - Name: Vu Hoang
#  - Email: hoangvubrvt@gmail.com
# At html_js_css_41.pdf:
#  - Name: TRẦN VĂN HÙNG
#  - Email: vanhung.tran.it@gmail.com
# At html_js_css_42.pdf:
#  - Name: Dang Ha T am
#  - Email: danghatam@gmail.com
# At html_js_css_43.pdf:
#  - Name: TAT TUAN PHONG
#  - Email: tattuanphong2005@gmail.com
# At html_js_css_44.pdf:
#  - Name: PHAM THAI HIEN
# At html_js_css_45.pdf:
#  - Name: Dang Nhat Minh
#  - Email: minh.dangnhat@hotmail.com
# At html_js_css_46.pdf:
#  - Name: ĐỨC TIẾN
# At html_js_css_47.pdf:
#  - Name: BAO DIEN
#  - Email: thienphuc1410@gmail.com
# At html_js_css_48.pdf:
#  - Name: THIEN  NGUYEN
#  - Email: nguyenphongthien@gmail.com
# At html_js_css_49.pdf:
#  - Name: TONG DINH THUONG
#  - Email: dinhthuong02@gmail.com
# At html_js_css_50.pdf:
#  - Name: Luong Ngo
#  - Email: ngocongluong@gmail.com
# At ios_01.pdf:
#  - Name: NGUYỄN DUY HẢO
#  - Email: nguyenduyhao1111@gmail.com
# At ios_02.pdf:
#  - Name: Hà Hải Dương
# At ios_03.pdf:
# At ios_04.pdf:
#  - Name: Phung Minh Tri
#  - Email: minhtriphung@gmail.com
# At ios_05.pdf:
#  - Name: NGUYEN VAN PHU
#  - Email: phuhitec@gmail.com
# At ios_06.pdf:
#  - Name: Thai Hoang Ho
#  - Email: hthoang88@gmail.com
# At ios_07.pdf:
#  - Name: Hoang	Phan	Quang
#  - Email: quanghoang0101@yahoo.com.vn
# At ios_08.pdf:
#  - Name: HOÀNG THẾ HÙNG
# At ios_09.pdf:
#  - Name: DANG DUNG
#  - Email: anthonydangdung@gmail.com
# At ios_10.pdf:
#  - Name: Nguyen THI THU THUY
#  - Email: amynguyen0505@gmail.com
# At ios_11.pdf:
#  - Name: VO QUOC KHANH
#  - Email: khanhvo1809@gmail.com
# At ios_12.pdf:
#  - Name: Pham Dang Duy Khanh
#  - Email: khanh.phamdd@gmail.com
# At ios_13.pdf:
#  - Name: PHAM DUY TIEN
#  - Email: phduytien4891@gmail.com
# At ios_14.pdf:
#  - Name: Luong Quy Tinh Ha
#  - Email: haluongvn{at}gmail{dot}com
# At ios_15.pdf:
#  - Name: NameNguyễn Thông Thái
#  - Email: EmailUchihathai105@gmail.com
# At ios_16.pdf:
#  - Name: KHA TUAN PHAT
#  - Email: phatkhatuan@gmail.com
# At ios_17.pdf:
#  - Name: Huynh Hong Phuoc
# At ios_18.pdf:
#  - Name: NGUYEN MINH THONG
#  - Email: playerthong@yahoo.com
# At ios_19.pdf:
#  - Name: NAMENGUYEN TAN THO
#  - Email: Thomasnguyendev@gmail
# At ios_20.pdf:
#  - Name: NGUYEN VAN DONG
#  - Email: dongnv1991@gmail.com
# At ios_21.pdf:
#  - Name: Le Bui Duc
#  - Email: lebuiduc@yahoo.com
# At ios_22.pdf:
#  - Name: HIEN NGOC NGUYEN
#  - Email: nnhien1991@gmail.com
# At ios_23.pdf:
#  - Name: NGUYEN KHAC CHAN
#  - Email: khacchan@gmail.com
# At ios_24.pdf:
#  - Name: HOA QUOC BAO
#  - Email: hqbao15121991@gmail.com
# At ios_25.pdf:
#  - Name: TRAN DUC TRINH
#  - Email: trinhduc20@gmail.com
# At ios_26.pdf:
#  - Name: MR ROBERT TRUONGPersonal
# At ios_27.pdf:
#  - Name: Nguyen Minh
#  - Email: phucnguyenpr@gmail.com
# At ios_28.pdf:
#  - Name: NAM QUOC DAM
#  - Email: namdq1969@gmail.com
# At ios_29.pdf:
#  - Name: Nguyen Hoang Dung
#  - Email: dungnguyen5589@gmail.com
# At ios_30.pdf:
#  - Name: Tran Huu Tam
#  - Email: tranhuutam2001@yahoo.com
# At ios_31.pdf:
#  - Name: Hanh VoiOS
# At ios_32.pdf:
#  - Name: NAMENGUYEN TAN THO
#  - Email: Thomasnguyendev@gmail
# At ios_33.pdf:
#  - Name: NGUYEN VAN LUAN
#  - Email: luanpro23@gmail.com
# At ios_34.pdf:
#  - Name: Nguyen Duc Chinh
#  - Email: ducchinhdl@gmail.com
# At ios_35.pdf:
#  - Name: Vinh Huynh
#  - Email: huhuvipi@gmail.com
# At ios_36.pdf:
#  - Name: LE DUY THANH
#  - Email: thanh@pizzathieves.com
# At ios_37.pdf:
#  - Name: Trinh Tien
#  - Email: trinhtienhai@gmail.com
# At ios_39.pdf:
#  - Name: TONG XUAN TRUONG
#  - Email: david.truong.tong@gmail.com
# At ios_40.pdf:
# At ios_41.pdf:
#  - Name: Minh-Hoang Nguyen
# At ios_42.pdf:
#  - Name: Nguyen Huy Son
# At ios_43.pdf:
#  - Name: NGUYEN HAI DANG
# At ios_44.pdf:
#  - Name: Nguyen Minh Tai
#  - Email: minhtai306@gmail.com
# At ios_45.pdf:
#  - Name: Nguyen Tan Hung
#  - Email: tanhung0107@gmail.com
# At ios_46.pdf:
#  - Name: Ha Xuan Hoan
#  - Email: vnhauc@gmail.com
# At ios_47.pdf:
#  - Name: NameNguyễn Thông Thái
#  - Email: EmailUchihathai105@gmail.com
# At ios_48.pdf:
#  - Name: Tống Bảo Trung
#  - Email: tongtrung90@gmail.com
# At ios_49.pdf:
#  - Name: Nguyễn Thành Tâm
#  - Email: kenjo8892@gmail.com
# At ios_50.pdf:
#  - Name: Lê Tùng Chinh
#  - Name: Lê Tùng Chinh
#  - Email: tungchinhbt@gmail.com
#  - Email: tungchinhbt@gmail.com
